# %%
import pandas as pd
import os
import numpy as np

from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from catboost import CatBoostClassifier, Pool
from bayes_opt import BayesianOptimization

data_path = '../../data'

random_seed = 20
import json
path = '../code/para_dict/data_list.json'
with open(path,'r',encoding='utf-8') as f:
    para = json.loads(f.read())
    
data_list= para['data_list_FE_AN7']
delete_list = para['delete_list_overfit1']

def load_data(data_list):
    data=[]
    for d in data_list:
        x = pd.read_csv('../data/preprocess/{}'.format(d))
        x_null = x.isnull().sum()
        
        print('\n',d,x.shape)
        print("Null columns:\n",x_null[x_null>0])

        if (d=='FE_data1.csv') or (d=='FE_data2.csv'):
            x.fillna(value=-1,inplace=True)
        
        if d[:8]=='FE_data9':
            if d!='FE_data9_raw.csv':
                x = x.drop(columns=['bacno_shift1','bacno_shiftm1'])
        data.append(x)

    all_data = pd.concat(data,axis=1)
    del data
    all_data_numsum = all_data.isnull().sum()
    print('ALL data shape:',all_data.shape)
    print('ALL data null:')
    print(all_data_numsum[all_data_numsum>0])
    return all_data


    
    
all_data = load_data(data_list)
category_list=['csmcu','hcefg','stscd','scity','stocn','mcc','acqic',\
                'mchno','etymd','contp','locdt_week']
#                 'ovrlt','insfg','ecfg',\
# 'cano_only_consecutive_stscd2','bacno_consecutive_and_only_ecfg','bacno_consecutive_and_only_ecfg',\
# 'cano_lastday_use_twokind','cano_lastlocdt2','bacno_stscd_equal2','bacno_ecfg_equal1']
## mode
for c in all_data.columns:
    print(c)
print(all_data.dtypes)

for c in category_list:
    if all_data[c].dtypes == 'float64':
        all_data[c] = all_data[c].astype('int')
    all_data[c]=all_data[c].astype('category')

for c in all_data.columns[all_data.dtypes==bool]:
    all_data[c]=all_data[c].map({True:1,False:0})
    print(all_data[c].value_counts())

bool_list= ['cano_lastlocdt2_shift1','cano_lastlocdt2_shiftm1','bacno_stscd_equal2_shift1','bacno_stscd_equal2_shiftm1',\
            'bacno_ecfg_equal1_shift1','bacno_ecfg_equal1_shiftm1']
for c in bool_list:
    all_data[c]=all_data[c].map({'True':1,'False':0,'-1':-1})
    print(c)
    print(all_data[c].value_counts(dropna=False))
    
# for c in all_data.columns:
#     print(all_data[c].value_counts().head())
    
## 切三種不同的訓練集驗證
X_train1 = all_data[all_data['locdt']<=60].drop(columns=delete_list)
y_train1 = all_data[all_data['locdt']<=60]['fraud_ind']
X_test1 = all_data[(all_data['locdt']>60) & (all_data['locdt']<=90)].drop(columns=delete_list)

y_test1 = all_data[(all_data['locdt']>60) & (all_data['locdt']<=90)]['fraud_ind']

categorical_features_indices = np.where(X_train1.columns.isin(category_list))[0]
print(X_train1.dtypes[categorical_features_indices])

param_cat={
    'loss_function':'Logloss',
    'eval_metric':'F1',
    
    'iterations':10000,
    'scale_pos_weight':1,
    'target_border':0.5,
    'random_seed':random_seed,
    'thread_count':1,
    'task_type':"GPU",
    'devices':'0:1',
    'verbose':20,
    'boosting_type':'Ordered',

    # 'min_data_in_leaf':1,
    # 'has_time':True,

    'learning_rate':0.1,
    'l2_leaf_reg':20,#20
    'depth':7,
#     'max_leaves':31,
    'bagging_temperature':0.3,#10
    'random_strength':10,
    # 'rsm':0.8,

    # 'fold_permutation_block':1,
    # 'feature_border_type':'MinEntropy',
    # 'boosting_type':'Ordered',
    # 'leaf_estimation_backtracking':'Armijo',
    
    'one_hot_max_size':200,
#     'grow_policy':'Lossguide',
}


param_range={
    'depth':(5,15.9),
    'max_leaves':(31,31.5),#(20,45),
    'l2_leaf_reg':(1,100),#(5,50),
    'bagging_temperature':(0.01,5)#(0.1,5),    
}

def cat_train(depth,max_leaves,l2_leaf_reg,bagging_temperature):
    param_cat['depth']=int(depth)
    param_cat['max_leaves']=int(max_leaves)
    param_cat['l2_leaf_reg']=l2_leaf_reg
    param_cat['bagging_temperature']=bagging_temperature
    
    model = CatBoostClassifier(**param_cat)
    model.fit(X_train1, y_train1,
    cat_features=categorical_features_indices,    
    eval_set=(X_test1, y_test1),
    early_stopping_rounds=1000,
    verbose=500) 
     
    score_max = model.get_best_score()['validation']['F1:use_weights=true']
    print(int(depth),int(max_leaves),l2_leaf_reg,bagging_temperature)
    print(score_max)
    
    with open('Bayes_result.txt','a') as f:
        print('depth',int(depth),file=f)
        print('max_leaves',int(max_leaves),file=f)
        print('l2_leaf_reg',l2_leaf_reg,file=f)
        print('bagging_temperature',bagging_temperature,file=f)
        print(score_max,file=f)
        print('',file=f)
    
    return score_max

with open('Bayes_result.txt','a') as f:
    print(data_list,file=f)
    print(delete_list,file=f)
    
cat_opt = BayesianOptimization(cat_train,param_range) 
cat_opt.maximize(n_iter=150, init_points=random_seed)
print(cat_opt.max)
with open('Bayes_result.txt','a') as f:
    print('Max para',cat_opt.max,file=f)

# model = CatBoostClassifier(**param_cat)
# model.fit(
#     X_train1, y_train1,
#     cat_features=categorical_features_indices,    
#     eval_set=(X_test1, y_test1),
#     verbose=20
# )
# print('Model is fitted: ' + str(model.is_fitted()))
# print('Model params:')
# print(model.get_params())
# Out:
#  raw_data.csv (1943452, 23)
# Null columns:
#  fraud_ind    421665
# dtype: int64
#
#  FE_data1.csv (1943452, 56)
# Null columns:
#  cano_conam_skew      92612
# cano_conam_kurt     155720
# cano_conam_var       38678
# bacno_locdt_skew     58303
# bacno_locdt_kurt    101191
# cano_locdt_skew      92612
# cano_locdt_kurt     155720
# dtype: int64
#
#  FE_data2.csv (1943452, 30)
# Null columns:
#  Series([], dtype: int64)
#
#  FE_data2_2.csv (1943452, 31)
# Null columns:
#  Series([], dtype: int64)
#
#  FE_data3.csv (1943452, 9)
# Null columns:
#  Series([], dtype: int64)
#
#  FE_data4.csv (1943452, 4)
# Null columns:
#  Series([], dtype: int64)
#
#  FE_data4_2.csv (1943452, 3)
# Null columns:
#  Series([], dtype: int64)
#
#  FE_data5.csv (1943452, 4)
# Null columns:
#  Series([], dtype: int64)
#
#  FE_data6.csv (1943452, 17)
# Null columns:
#  Series([], dtype: int64)
#
#  FE_data8.csv (1943452, 11)
# Null columns:
#  Series([], dtype: int64)
#
#  FE_data9_3.csv (1943452, 20)
# Null columns:
#  Series([], dtype: int64)
#
#  FE_data9_4.csv (1943452, 10)
# Null columns:
#  Series([], dtype: int64)
#
#  FE_data9_4_2.csv (1943452, 8)
# Null columns:
#  Series([], dtype: int64)
#
#  FE_data9_5.csv (1943452, 10)
# Null columns:
#  Series([], dtype: int64)
#
#  FE_data9_8.csv (1943452, 24)
# Null columns:
#  Series([], dtype: int64)
#
#  FE_data9_raw.csv (1943452, 36)
# Null columns:
#  Series([], dtype: int64)
#
#  pca_feature.csv (1943452, 5)
# Null columns:
#  Series([], dtype: int64)
#
#  isolationtree_feature.csv (1943452, 4)
# Null columns:
#  Series([], dtype: int64)
#
#  kmeans_feature.csv (1943452, 5)
# Null columns:
#  Series([], dtype: int64)
#
#  svm_rbf_feature.csv (1943452, 1)
# Null columns:
#  Series([], dtype: int64)
# ALL data shape: (1943452, 301)
# ALL data null:
# fraud_ind    421665
# dtype: int64
# acqic
# bacno
# cano
# conam
# contp
# csmcu
# ecfg
# etymd
# flbmk
# flg_3dsmk
# fraud_ind
# hcefg
# insfg
# iterm
# locdt
# loctm
# mcc
# mchno
# ovrlt
# scity
# stocn
# stscd
# txkey
# bacno_cano_nunique
# bacno_txkey_nunique
# conam_log
# bacno_mean_conam
# bacno_scale_conam
# cano_mean_conam
# cano_scale_conam
# cano_conam_skew
# cano_conam_kurt
# cano_conam_mean
# cano_conam_var
# bacno_max_conam
# bacno_ismax_conam
# bacno_min_conam
# bacno_ismin_conam
# bacno_ratio_ecfg
# cano_ratio_ecfg
# locdt_week
# loctm_hr
# bacno_locdt_skew
# bacno_locdt_kurt
# cano_locdt_skew
# cano_locdt_kurt
# bacno_stocn_mode
# bacno_scity_mode
# bacno_csmcu_mode
# bacno_stocn_ismode
# bacno_scity_ismode
# bacno_csmcu_ismode
# cano_stocn_mode
# cano_scity_mode
# cano_csmcu_mode
# cano_stocn_ismode
# cano_scity_ismode
# cano_csmcu_ismode
# mchno_fraud_mean
# mcc_fraud_mean
# acqic_fraud_mean
# mchno_bacno_nunique
# acqic_bacno_nunique
# mcc_bacno_nunique
# stocn_bacno_nunique
# scity_bacno_nunique
# csmcu_bacno_nunique
# mchno_cano_nunique
# acqic_cano_nunique
# mcc_cano_nunique
# stocn_cano_nunique
# scity_cano_nunique
# csmcu_cano_nunique
# mchno_value_counts_all
# acqic_value_counts_all
# mcc_value_counts_all
# stocn_value_counts_all
# scity_value_counts_all
# csmcu_value_counts_all
# bacno_stocn_nunique
# stocn_value_counts
# stocn_ratio
# bacno_csmcu_nunique
# csmcu_value_counts
# csmcu_ratio
# bacno_mchno_nunique
# mchno_value_counts
# mchno_ratio
# bacno_acqic_nunique
# acqic_value_counts
# acqic_ratio
# bacno_mcc_nunique
# mcc_value_counts
# mcc_ratio
# bacno_scity_nunique
# scity_value_counts
# scity_ratio
# bacno_contp_nunique
# contp_value_counts
# contp_ratio
# bacno_etymd_nunique
# etymd_value_counts
# etymd_ratio
# bacno_stscd_nunique
# stscd_value_counts
# stscd_ratio
# bacno_hcefg_nunique
# hcefg_value_counts
# hcefg_ratio
# cano_txkey_nunique
# cano_stocn_nunique
# stocn_value_counts_cano
# stocn_ratio_cano
# cano_csmcu_nunique
# csmcu_value_counts_cano
# csmcu_ratio_cano
# cano_mchno_nunique
# mchno_value_counts_cano
# mchno_ratio_cano
# cano_acqic_nunique
# acqic_value_counts_cano
# acqic_ratio_cano
# cano_mcc_nunique
# mcc_value_counts_cano
# mcc_ratio_cano
# cano_scity_nunique
# scity_value_counts_cano
# scity_ratio_cano
# cano_contp_nunique
# contp_value_counts_cano
# contp_ratio_cano
# cano_etymd_nunique
# etymd_value_counts_cano
# etymd_ratio_cano
# cano_stscd_nunique
# stscd_value_counts_cano
# stscd_ratio_cano
# cano_hcefg_nunique
# hcefg_value_counts_cano
# hcefg_ratio_cano
# cano_only_consecutive_stscd2
# bacno_consecutive_and_only_ecfg
# cano_lastday_use
# cano_lastday_use_twokind
# cano_lastlocdt
# bacno_lastlocdt
# cano_lastlocdt2
# bacno_stscd_equal2
# bacno_ecfg_equal1
# bacno_1_count
# bacno_2day_count
# bacno_3day_count
# bacno_7day_count
# bacno_2day_after_count
# bacno_3day_after_count
# bacno_7day_after_count
# bacno_cano_changetimes
# cano_change_ratio
# bacno_locdt_diff
# bacno_loctm_diff
# bacno_cano_monoincrease
# bacno_contp_mode
# cano_contp_mode
# bacno_etymd_mode
# cano_etymd_mode
# bacno_mchno_mode
# cano_mchno_mode
# bacno_acqic_mode
# cano_acqic_mode
# bacno_mcc_mode
# cano_mcc_mode
# bacno_ecfg_mode
# cano_ecfg_mode
# bacno_hcefg_mode
# cano_hcefg_mode
# bacno_stscd_mode
# cano_stscd_mode
# bacno_diff1_sum
# bacno_diff2_sum
# cano_diff1_sum
# cano_diff2_sum
# bacno_diff_m1_sum
# bacno_diff_m2_sum
# cano_diff_m1_sum
# cano_diff_m2_sum
# bacno_stocn_lastday
# bacno_scity_lastday
# bacno_csmcu_lastday
# cano_only_consecutive_stscd2_shift1
# cano_only_consecutive_stscd2_shiftm1
# bacno_consecutive_and_only_ecfg_shift1
# bacno_consecutive_and_only_ecfg_shiftm1
# cano_lastday_use_shift1
# cano_lastday_use_shiftm1
# cano_lastday_use_twokind_shift1
# cano_lastday_use_twokind_shiftm1
# cano_lastlocdt_shift1
# cano_lastlocdt_shiftm1
# bacno_lastlocdt_shift1
# bacno_lastlocdt_shiftm1
# cano_lastlocdt2_shift1
# cano_lastlocdt2_shiftm1
# bacno_stscd_equal2_shift1
# bacno_stscd_equal2_shiftm1
# bacno_ecfg_equal1_shift1
# bacno_ecfg_equal1_shiftm1
# bacno_1_count_shift1
# bacno_1_count_shiftm1
# bacno_2day_count_shift1
# bacno_2day_count_shiftm1
# bacno_3day_count_shift1
# bacno_3day_count_shiftm1
# bacno_7day_count_shift1
# bacno_7day_count_shiftm1
# bacno_2day_after_count_shift1
# bacno_2day_after_count_shiftm1
# bacno_3day_after_count_shift1
# bacno_3day_after_count_shiftm1
# bacno_7day_after_count_shift1
# bacno_7day_after_count_shiftm1
# bacno_cano_changetimes_shift1
# bacno_cano_changetimes_shiftm1
# cano_change_ratio_shift1
# cano_change_ratio_shiftm1
# bacno_locdt_diff_shift1
# bacno_locdt_diff_shiftm1
# bacno_loctm_diff_shift1
# bacno_loctm_diff_shiftm1
# bacno_diff1_sum_shift1
# bacno_diff1_sum_shiftm1
# bacno_diff2_sum_shift1
# bacno_diff2_sum_shiftm1
# cano_diff1_sum_shift1
# cano_diff1_sum_shiftm1
# cano_diff2_sum_shift1
# cano_diff2_sum_shiftm1
# bacno_diff_m1_sum_shift1
# bacno_diff_m1_sum_shiftm1
# bacno_diff_m2_sum_shift1
# bacno_diff_m2_sum_shiftm1
# cano_diff_m1_sum_shift1
# cano_diff_m1_sum_shiftm1
# cano_diff_m2_sum_shift1
# cano_diff_m2_sum_shiftm1
# bacno_stocn_lastday_shift1
# bacno_stocn_lastday_shiftm1
# bacno_scity_lastday_shift1
# bacno_scity_lastday_shiftm1
# bacno_csmcu_lastday_shift1
# bacno_csmcu_lastday_shiftm1
# acqic_shift1
# acqic_shiftm1
# cano_shift1
# cano_shiftm1
# conam_shift1
# conam_shiftm1
# contp_shift1
# contp_shiftm1
# csmcu_shift1
# csmcu_shiftm1
# ecfg_shift1
# ecfg_shiftm1
# etymd_shift1
# etymd_shiftm1
# flbmk_shift1
# flbmk_shiftm1
# flg_3dsmk_shift1
# flg_3dsmk_shiftm1
# hcefg_shift1
# hcefg_shiftm1
# insfg_shift1
# insfg_shiftm1
# iterm_shift1
# iterm_shiftm1
# mcc_shift1
# mcc_shiftm1
# mchno_shift1
# mchno_shiftm1
# ovrlt_shift1
# ovrlt_shiftm1
# scity_shift1
# scity_shiftm1
# stocn_shift1
# stocn_shiftm1
# stscd_shift1
# stscd_shiftm1
# pca2_feature_1
# pca2_feature_2
# pca3_feature_1
# pca3_feature_2
# pca3_feature_3
# isolationtree_all_feature
# isolationtree_all_feature2
# isolationtree_all_feature3
# isolationtree_all_feature4
# kmeans_all_feature
# kmeans_all_feature2
# kmeans_all_feature3
# kmeans_all_feature4
# kmeans_all_feature5
# svm_rbf
# acqic                           int64
# bacno                           int64
# cano                            int64
# conam                         float64
# contp                           int64
# csmcu                           int64
# ecfg                            int64
# etymd                           int64
# flbmk                         float64
# flg_3dsmk                     float64
# fraud_ind                     float64
# hcefg                           int64
# insfg                           int64
# iterm                           int64
# locdt                           int64
# loctm                           int64
# mcc                             int64
# mchno                           int64
# ovrlt                           int64
# scity                           int64
# stocn                           int64
# stscd                           int64
# txkey                           int64
# bacno_cano_nunique              int64
# bacno_txkey_nunique             int64
# conam_log                     float64
# bacno_mean_conam              float64
# bacno_scale_conam             float64
# cano_mean_conam               float64
# cano_scale_conam              float64
#                                ...
# insfg_shiftm1                 float64
# iterm_shift1                  float64
# iterm_shiftm1                 float64
# mcc_shift1                    float64
# mcc_shiftm1                   float64
# mchno_shift1                  float64
# mchno_shiftm1                 float64
# ovrlt_shift1                  float64
# ovrlt_shiftm1                 float64
# scity_shift1                  float64
# scity_shiftm1                 float64
# stocn_shift1                  float64
# stocn_shiftm1                 float64
# stscd_shift1                  float64
# stscd_shiftm1                 float64
# pca2_feature_1                float64
# pca2_feature_2                float64
# pca3_feature_1                float64
# pca3_feature_2                float64
# pca3_feature_3                float64
# isolationtree_all_feature     float64
# isolationtree_all_feature2    float64
# isolationtree_all_feature3    float64
# isolationtree_all_feature4    float64
# kmeans_all_feature            float64
# kmeans_all_feature2           float64
# kmeans_all_feature3           float64
# kmeans_all_feature4           float64
# kmeans_all_feature5           float64
# svm_rbf                       float64
# Length: 301, dtype: object
# 0    1750491
# 1     192961
# Name: bacno_ismax_conam, dtype: int64
# 0    1687135
# 1     256317
# Name: bacno_ismin_conam, dtype: int64
# 1    1750733
# 0     192719
# Name: bacno_stocn_ismode, dtype: int64
# 1    1209667
# 0     733785
# Name: bacno_scity_ismode, dtype: int64
# 1    1682930
# 0     260522
# Name: bacno_csmcu_ismode, dtype: int64
# 1    1773728
# 0     169724
# Name: cano_stocn_ismode, dtype: int64
# 1    1270111
# 0     673341
# Name: cano_scity_ismode, dtype: int64
# 1    1719562
# 0     223890
# Name: cano_csmcu_ismode, dtype: int64
# 0    1874608
# 1      68844
# Name: cano_lastlocdt2, dtype: int64
# 0    1941042
# 1       2410
# Name: bacno_stscd_equal2, dtype: int64
# 0    1922205
# 1      21247
# Name: bacno_ecfg_equal1, dtype: int64
# 1    1258954
# 0     684498
# Name: bacno_cano_monoincrease, dtype: int64
# cano_lastlocdt2_shift1
#  0    1711423
# -1     163185
#  1      68844
# Name: cano_lastlocdt2_shift1, dtype: int64
# cano_lastlocdt2_shiftm1
#  0    1715834
# -1     163185
#  1      64433
# Name: cano_lastlocdt2_shiftm1, dtype: int64
# bacno_stscd_equal2_shift1
#  0    1778462
# -1     163185
#  1       1805
# Name: bacno_stscd_equal2_shift1, dtype: int64
# bacno_stscd_equal2_shiftm1
#  0    1778191
# -1     163185
#  1       2076
# Name: bacno_stscd_equal2_shiftm1, dtype: int64
# bacno_ecfg_equal1_shift1
#  0    1766506
# -1     163185
#  1      13761
# Name: bacno_ecfg_equal1_shift1, dtype: int64
# bacno_ecfg_equal1_shiftm1
#  0    1766439
# -1     163185
#  1      13828
# Name: bacno_ecfg_equal1_shiftm1, dtype: int64
# acqic         category
# contp         category
# csmcu         category
# etymd         category
# hcefg         category
# mcc           category
# mchno         category
# scity         category
# stocn         category
# stscd         category
# locdt_week    category
# dtype: object
# |   iter    |  target   | baggin... |   depth   | l2_lea... | max_le... |
# -------------------------------------------------------------------------
# 0:	learn: 0.4425831	test: 0.3417251	best: 0.3417251 (0)	total: 250ms	remaining: 41m 38s
# 500:	learn: 0.8822707	test: 0.6134527	best: 0.6134527 (500)	total: 1m 45s	remaining: 33m 27s
# 1000:	learn: 0.9188966	test: 0.6256923	best: 0.6265086 (896)	total: 3m 30s	remaining: 31m 31s
# 1500:	learn: 0.9353506	test: 0.6287263	best: 0.6294207 (1458)	total: 5m 14s	remaining: 29m 41s
# 2000:	learn: 0.9467496	test: 0.6286828	best: 0.6311342 (1861)	total: 6m 58s	remaining: 27m 54s
# 2500:	learn: 0.9535356	test: 0.6304301	best: 0.6316812 (2427)	total: 8m 43s	remaining: 26m 9s
# 3000:	learn: 0.9587207	test: 0.6325844	best: 0.6331201 (2844)	total: 10m 27s	remaining: 24m 23s
# 3500:	learn: 0.9640583	test: 0.6355242	best: 0.6356926 (3374)	total: 12m 12s	remaining: 22m 40s
# 4000:	learn: 0.9676335	test: 0.6376780	best: 0.6388345 (3762)	total: 13m 57s	remaining: 20m 56s
# 4500:	learn: 0.9703256	test: 0.6377695	best: 0.6388345 (3762)	total: 15m 41s	remaining: 19m 10s
# bestTest = 0.6388345292
# bestIteration = 3762
# Shrink model to first 3763 iterations.
# 8 31 39.208404118622916 0.43339310555073945
# 0.6388345292454881
# |  1        |  0.6388   |  0.4334   |  8.622    |  39.21    |  31.3     |
# 0:	learn: 0.4419914	test: 0.3410405	best: 0.3410405 (0)	total: 658ms	remaining: 1h 49m 34s
# 500:	learn: 0.8356538	test: 0.5973003	best: 0.5982906 (494)	total: 5m 18s	remaining: 1h 40m 43s
# 1000:	learn: 0.8610697	test: 0.6054490	best: 0.6055375 (999)	total: 10m 35s	remaining: 1h 35m 15s
# 1500:	learn: 0.8739436	test: 0.6113165	best: 0.6118885 (1491)	total: 15m 50s	remaining: 1h 29m 43s
# 2000:	learn: 0.8862191	test: 0.6100179	best: 0.6133333 (1590)	total: 21m 6s	remaining: 1h 24m 21s
# 2500:	learn: 0.8944199	test: 0.6135298	best: 0.6141329 (2376)	total: 26m 21s	remaining: 1h 19m 1s
# 3000:	learn: 0.9007959	test: 0.6106392	best: 0.6141329 (2376)	total: 31m 36s	remaining: 1h 13m 42s
# bestTest = 0.6141328578
# bestIteration = 2376
# Shrink model to first 2377 iterations.
# 10 31 77.71028161676065 2.6650472872159017
# 0.6141328577797592
# |  2        |  0.6141   |  2.665    |  10.91    |  77.71    |  31.11    |
